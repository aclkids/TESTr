# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Alice Long__
# Career choice: Data Scientist

# %% [markdown]
# _I am interested in data science because that is what I have been trained to do. When I received my Ph. D., I did not know that industry jobs for data scientists existed. I am now pivoting my career to the data scientist path so that I can use this skill more in my work_

# %% [markdown]
# ### The code in cell 5 will complete a simple math equation (5+15).

# %%
5+15
# Out:
# 20

# %% [markdown]
# # Cell 6 includes formatting
# # Bulleted list
# *  Green
# *  Orange
# *  Yellow
#
# ### Horizontal Rule
#
# ***
#
# ## Images in a Numbered List
# 1. Image 1
# ![blog_San_Francisco_Peaks_Shane_McDermott.jpg](attachment:b3f6bbeb-1a95-44a7-a4be-9bd5686c1ab8.jpg)
# 2. Image 2
# ![geography of the peaks.webp](attachment:40a8f0ca-6dd0-47e9-8063-78112f0ad8df.webp)
#
# ***
# ## Link to an external site
# __[link text](http://https://acaai.org/allergies/allergic-conditions/skin-allergy/hives/)__
